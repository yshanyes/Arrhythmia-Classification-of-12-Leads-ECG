# %%
from resnet_ecg.utils import one_hot,get_batches
from resnet_ecg.ecg_preprocess import ecg_preprocessing
from resnet_ecg.densemodel import Net
from resnet_ecg.ecg import resnetmodel
# Out:
# Using TensorFlow backend.

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
from utils import extract_basic_features

import wfdb
import os
import wfdb.processing as wp
import matplotlib.pyplot as plt
from scipy import signal
from utils import find_noise_features, extract_basic_features
import shutil
import json
import time
import random as rn
#from lightgbm import LGBMClassifier
from scipy import sparse
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold,StratifiedKFold
#from xgboost import XGBClassifier

# %%
from keras.utils import to_categorical
from keras.optimizers import SGD,Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler,EarlyStopping,ReduceLROnPlateau
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF
from sklearn.model_selection import StratifiedKFold

config = tf.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
config.gpu_options.per_process_gpu_memory_fraction = 0.8

session = tf.Session(config=config)

KTF.set_session(session )

# %%
os.environ['PYTHONHASHSEED'] = '0'

np.random.seed(42)
rn.seed(12345)

tf.set_random_seed(1234)

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import scipy.io as sio
train_dataset_path = os.getcwd()+"/Train/"
val_dataset_path = os.getcwd()+"/Val/"

# %%
train_files = os.listdir(train_dataset_path)
train_files.sort()
val_files = os.listdir(val_dataset_path)
val_files.sort()

# %%
labels = pd.read_csv("reference.csv")
labels.head()
# Out:
#    File_name  label1  label2  label3  label4  label5  label6  label7  label8
# 0  TRAIN0001       8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  TRAIN0002       8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2  TRAIN0003       8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  TRAIN0004       8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4  TRAIN0005       8     NaN     NaN     NaN     NaN     NaN     NaN     NaN

# %%
from keras.layers import Input
from keras.models import Model,load_model

config_file = './resnet_ecg/examples/cinc17/config.json'
params = json.load(open(config_file,'r'))
params.update({
        'input_shape':[2560,12],
        'num_categories':9
    })

inputs0 = Input(shape=(2560,12))
inputs1 = Input(shape=(2560,12))
inputs2 = Input(shape=(2560,12))
inputs3 = Input(shape=(2560,12))
inputs4 = Input(shape=(2560,12))
inputs5 = Input(shape=(2560,12))
inputs6 = Input(shape=(2560,12))
inputs7 = Input(shape=(2560,12))
inputs8 = Input(shape=(2560,12))
inputs9 = Input(shape=(2560,12))

inputs_list = [inputs0,inputs1,inputs2,inputs3,inputs4,inputs5,inputs6,inputs7,inputs8,inputs9]

outputs = resnetmodel.build_network(inputs_list,0.5,num_classes=9,**params)
model = Model(inputs =inputs_list,outputs=outputs)
# Out:
# WARNING:tensorflow:From /home/JDWorkSpace/vyuf0458/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/JDWorkSpace/uuser/anaconda3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, 2560, 12)     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 2560, 12)     0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 2560, 32)     6176        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 2560, 32)     6176        input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 2560, 32)     6176        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 2560, 32)     6176        input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_101 (Conv1D)             (None, 2560, 32)     6176        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_126 (Conv1D)             (None, 2560, 32)     6176        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_151 (Conv1D)             (None, 2560, 32)     6176        input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_176 (Conv1D)             (None, 2560, 32)     6176        input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_201 (Conv1D)             (None, 2560, 32)     6176        input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_226 (Conv1D)             (None, 2560, 32)     6176        input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 2560, 32)     128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 2560, 32)     128         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 2560, 32)     128         conv1d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 2560, 32)     128         conv1d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 2560, 32)     128         conv1d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 2560, 32)     128         conv1d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 2560, 32)     128         conv1d_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 2560, 32)     128         conv1d_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 2560, 32)     128         conv1d_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 2560, 32)     128         conv1d_226[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2560, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 2560, 32)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 2560, 32)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 2560, 32)     0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 2560, 32)     0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 2560, 32)     0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 2560, 32)     0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 2560, 32)     0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 2560, 32)     0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 2560, 32)     0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2560, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 2560, 32)     0           activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 2560, 32)     0           activation_53[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 2560, 32)     0           activation_79[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 2560, 32)     0           activation_105[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 2560, 32)     0           activation_131[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 2560, 32)     0           activation_157[0][0]
# __________________________________________________________________________________________________
# dropout_99 (Dropout)            (None, 2560, 32)     0           activation_183[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 2560, 32)     0           activation_209[0][0]
# __________________________________________________________________________________________________
# dropout_127 (Dropout)           (None, 2560, 32)     0           activation_235[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 2560, 32)     16416       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 2560, 32)     16416       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 2560, 32)     16416       dropout_29[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 2560, 32)     16416       dropout_43[0][0]
# __________________________________________________________________________________________________
# conv1d_102 (Conv1D)             (None, 2560, 32)     16416       dropout_57[0][0]
# __________________________________________________________________________________________________
# conv1d_127 (Conv1D)             (None, 2560, 32)     16416       dropout_71[0][0]
# __________________________________________________________________________________________________
# conv1d_152 (Conv1D)             (None, 2560, 32)     16416       dropout_85[0][0]
# __________________________________________________________________________________________________
# conv1d_177 (Conv1D)             (None, 2560, 32)     16416       dropout_99[0][0]
# __________________________________________________________________________________________________
# conv1d_202 (Conv1D)             (None, 2560, 32)     16416       dropout_113[0][0]
# __________________________________________________________________________________________________
# conv1d_227 (Conv1D)             (None, 2560, 32)     16416       dropout_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2560, 32)     128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 2560, 32)     128         conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 2560, 32)     128         conv1d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 2560, 32)     128         conv1d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 2560, 32)     128         conv1d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 2560, 32)     128         conv1d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 2560, 32)     128         conv1d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 2560, 32)     128         conv1d_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 2560, 32)     128         conv1d_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 2560, 32)     128         conv1d_227[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2560, 32)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 2560, 32)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 2560, 32)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 2560, 32)     0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 2560, 32)     0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 2560, 32)     0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 2560, 32)     0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 2560, 32)     0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 2560, 32)     0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 2560, 32)     0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2560, 32)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 2560, 32)     0           activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 2560, 32)     0           activation_54[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 2560, 32)     0           activation_80[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 2560, 32)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# dropout_72 (Dropout)            (None, 2560, 32)     0           activation_132[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 2560, 32)     0           activation_158[0][0]
# __________________________________________________________________________________________________
# dropout_100 (Dropout)           (None, 2560, 32)     0           activation_184[0][0]
# __________________________________________________________________________________________________
# dropout_114 (Dropout)           (None, 2560, 32)     0           activation_210[0][0]
# __________________________________________________________________________________________________
# dropout_128 (Dropout)           (None, 2560, 32)     0           activation_236[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 2560, 32)     0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 2560, 32)     16416       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 2560, 32)     0           dropout_15[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 2560, 32)     16416       dropout_16[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_25 (MaxPooling1D) (None, 2560, 32)     0           dropout_29[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 2560, 32)     16416       dropout_30[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_37 (MaxPooling1D) (None, 2560, 32)     0           dropout_43[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 2560, 32)     16416       dropout_44[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_49 (MaxPooling1D) (None, 2560, 32)     0           dropout_57[0][0]
# __________________________________________________________________________________________________
# conv1d_103 (Conv1D)             (None, 2560, 32)     16416       dropout_58[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_61 (MaxPooling1D) (None, 2560, 32)     0           dropout_71[0][0]
# __________________________________________________________________________________________________
# conv1d_128 (Conv1D)             (None, 2560, 32)     16416       dropout_72[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_73 (MaxPooling1D) (None, 2560, 32)     0           dropout_85[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, 2560, 32)     16416       dropout_86[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_85 (MaxPooling1D) (None, 2560, 32)     0           dropout_99[0][0]
# __________________________________________________________________________________________________
# conv1d_178 (Conv1D)             (None, 2560, 32)     16416       dropout_100[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_97 (MaxPooling1D) (None, 2560, 32)     0           dropout_113[0][0]
# __________________________________________________________________________________________________
# conv1d_203 (Conv1D)             (None, 2560, 32)     16416       dropout_114[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_109 (MaxPooling1D (None, 2560, 32)     0           dropout_127[0][0]
# __________________________________________________________________________________________________
# conv1d_228 (Conv1D)             (None, 2560, 32)     16416       dropout_128[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 2560, 32)     0           max_pooling1d_1[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2560, 32)     0           max_pooling1d_13[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 2560, 32)     0           max_pooling1d_25[0][0]
#                                                                  conv1d_53[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 2560, 32)     0           max_pooling1d_37[0][0]
#                                                                  conv1d_78[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 2560, 32)     0           max_pooling1d_49[0][0]
#                                                                  conv1d_103[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 2560, 32)     0           max_pooling1d_61[0][0]
#                                                                  conv1d_128[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 2560, 32)     0           max_pooling1d_73[0][0]
#                                                                  conv1d_153[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 2560, 32)     0           max_pooling1d_85[0][0]
#                                                                  conv1d_178[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 2560, 32)     0           max_pooling1d_97[0][0]
#                                                                  conv1d_203[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 2560, 32)     0           max_pooling1d_109[0][0]
#                                                                  conv1d_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2560, 32)     128         add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 2560, 32)     128         add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 2560, 32)     128         add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 2560, 32)     128         add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 2560, 32)     128         add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 2560, 32)     128         add_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 2560, 32)     128         add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 2560, 32)     128         add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 2560, 32)     128         add_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 2560, 32)     128         add_109[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2560, 32)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 2560, 32)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 2560, 32)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 2560, 32)     0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 2560, 32)     0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 2560, 32)     0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 2560, 32)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 2560, 32)     0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 2560, 32)     0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 2560, 32)     0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1280, 32)     16416       activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 1280, 32)     16416       activation_29[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 1280, 32)     16416       activation_55[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 1280, 32)     16416       activation_81[0][0]
# __________________________________________________________________________________________________
# conv1d_104 (Conv1D)             (None, 1280, 32)     16416       activation_107[0][0]
# __________________________________________________________________________________________________
# conv1d_129 (Conv1D)             (None, 1280, 32)     16416       activation_133[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, 1280, 32)     16416       activation_159[0][0]
# __________________________________________________________________________________________________
# conv1d_179 (Conv1D)             (None, 1280, 32)     16416       activation_185[0][0]
# __________________________________________________________________________________________________
# conv1d_204 (Conv1D)             (None, 1280, 32)     16416       activation_211[0][0]
# __________________________________________________________________________________________________
# conv1d_229 (Conv1D)             (None, 1280, 32)     16416       activation_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1280, 32)     128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 1280, 32)     128         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 1280, 32)     128         conv1d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 1280, 32)     128         conv1d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 1280, 32)     128         conv1d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 1280, 32)     128         conv1d_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 1280, 32)     128         conv1d_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 1280, 32)     128         conv1d_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 1280, 32)     128         conv1d_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 1280, 32)     128         conv1d_229[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1280, 32)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 1280, 32)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 1280, 32)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 1280, 32)     0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 1280, 32)     0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 1280, 32)     0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 1280, 32)     0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 1280, 32)     0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 1280, 32)     0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 1280, 32)     0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1280, 32)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 1280, 32)     0           activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 1280, 32)     0           activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 1280, 32)     0           activation_82[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 1280, 32)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 1280, 32)     0           activation_134[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 1280, 32)     0           activation_160[0][0]
# __________________________________________________________________________________________________
# dropout_101 (Dropout)           (None, 1280, 32)     0           activation_186[0][0]
# __________________________________________________________________________________________________
# dropout_115 (Dropout)           (None, 1280, 32)     0           activation_212[0][0]
# __________________________________________________________________________________________________
# dropout_129 (Dropout)           (None, 1280, 32)     0           activation_238[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1280, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 1280, 32)     16416       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 1280, 32)     0           add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1280, 32)     16416       dropout_17[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_26 (MaxPooling1D) (None, 1280, 32)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 1280, 32)     16416       dropout_31[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_38 (MaxPooling1D) (None, 1280, 32)     0           add_37[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 1280, 32)     16416       dropout_45[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_50 (MaxPooling1D) (None, 1280, 32)     0           add_49[0][0]
# __________________________________________________________________________________________________
# conv1d_105 (Conv1D)             (None, 1280, 32)     16416       dropout_59[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_62 (MaxPooling1D) (None, 1280, 32)     0           add_61[0][0]
# __________________________________________________________________________________________________
# conv1d_130 (Conv1D)             (None, 1280, 32)     16416       dropout_73[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_74 (MaxPooling1D) (None, 1280, 32)     0           add_73[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, 1280, 32)     16416       dropout_87[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_86 (MaxPooling1D) (None, 1280, 32)     0           add_85[0][0]
# __________________________________________________________________________________________________
# conv1d_180 (Conv1D)             (None, 1280, 32)     16416       dropout_101[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_98 (MaxPooling1D) (None, 1280, 32)     0           add_97[0][0]
# __________________________________________________________________________________________________
# conv1d_205 (Conv1D)             (None, 1280, 32)     16416       dropout_115[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_110 (MaxPooling1D (None, 1280, 32)     0           add_109[0][0]
# __________________________________________________________________________________________________
# conv1d_230 (Conv1D)             (None, 1280, 32)     16416       dropout_129[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1280, 32)     0           max_pooling1d_2[0][0]
#                                                                  conv1d_5[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1280, 32)     0           max_pooling1d_14[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 1280, 32)     0           max_pooling1d_26[0][0]
#                                                                  conv1d_55[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 1280, 32)     0           max_pooling1d_38[0][0]
#                                                                  conv1d_80[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 1280, 32)     0           max_pooling1d_50[0][0]
#                                                                  conv1d_105[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 1280, 32)     0           max_pooling1d_62[0][0]
#                                                                  conv1d_130[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 1280, 32)     0           max_pooling1d_74[0][0]
#                                                                  conv1d_155[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 1280, 32)     0           max_pooling1d_86[0][0]
#                                                                  conv1d_180[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 1280, 32)     0           max_pooling1d_98[0][0]
#                                                                  conv1d_205[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 1280, 32)     0           max_pooling1d_110[0][0]
#                                                                  conv1d_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1280, 32)     128         add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 1280, 32)     128         add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 1280, 32)     128         add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 1280, 32)     128         add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 1280, 32)     128         add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 1280, 32)     128         add_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 1280, 32)     128         add_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 1280, 32)     128         add_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 1280, 32)     128         add_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 1280, 32)     128         add_110[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1280, 32)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 1280, 32)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 1280, 32)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 1280, 32)     0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 1280, 32)     0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 1280, 32)     0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 1280, 32)     0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 1280, 32)     0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 1280, 32)     0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 1280, 32)     0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1280, 32)     16416       activation_5[0][0]
# ...
# max_pooling1d_96 (MaxPooling1D) (None, 40, 128)      0           add_95[0][0]
# __________________________________________________________________________________________________
# conv1d_200 (Conv1D)             (None, 40, 128)      262272      dropout_111[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_108 (MaxPooling1D (None, 40, 128)      0           add_107[0][0]
# __________________________________________________________________________________________________
# conv1d_225 (Conv1D)             (None, 40, 128)      262272      dropout_125[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_120 (MaxPooling1D (None, 40, 128)      0           add_119[0][0]
# __________________________________________________________________________________________________
# conv1d_250 (Conv1D)             (None, 40, 128)      262272      dropout_139[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 40, 128)      0           max_pooling1d_12[0][0]
#                                                                  conv1d_25[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 40, 128)      0           max_pooling1d_24[0][0]
#                                                                  conv1d_50[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 40, 128)      0           max_pooling1d_36[0][0]
#                                                                  conv1d_75[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 40, 128)      0           max_pooling1d_48[0][0]
#                                                                  conv1d_100[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 40, 128)      0           max_pooling1d_60[0][0]
#                                                                  conv1d_125[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 40, 128)      0           max_pooling1d_72[0][0]
#                                                                  conv1d_150[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 40, 128)      0           max_pooling1d_84[0][0]
#                                                                  conv1d_175[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 40, 128)      0           max_pooling1d_96[0][0]
#                                                                  conv1d_200[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 40, 128)      0           max_pooling1d_108[0][0]
#                                                                  conv1d_225[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 40, 128)      0           max_pooling1d_120[0][0]
#                                                                  conv1d_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 40, 128)      512         add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 40, 128)      512         add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 40, 128)      512         add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 40, 128)      512         add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 40, 128)      512         add_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 40, 128)      512         add_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 40, 128)      512         add_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 40, 128)      512         add_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 40, 128)      512         add_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 40, 128)      512         add_120[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 40, 128)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 40, 128)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 40, 128)      0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 40, 128)      0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 40, 128)      0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 40, 128)      0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 40, 128)      0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 40, 128)      0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 40, 128)      0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 40, 128)      0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 40, 128)      0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 40, 128)      0           activation_51[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 40, 128)      0           activation_77[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 40, 128)      0           activation_103[0][0]
# __________________________________________________________________________________________________
# dropout_70 (Dropout)            (None, 40, 128)      0           activation_129[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 40, 128)      0           activation_155[0][0]
# __________________________________________________________________________________________________
# dropout_98 (Dropout)            (None, 40, 128)      0           activation_181[0][0]
# __________________________________________________________________________________________________
# dropout_112 (Dropout)           (None, 40, 128)      0           activation_207[0][0]
# __________________________________________________________________________________________________
# dropout_126 (Dropout)           (None, 40, 128)      0           activation_233[0][0]
# __________________________________________________________________________________________________
# dropout_140 (Dropout)           (None, 40, 128)      0           activation_259[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 1, 128)       0           dropout_14[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 1, 128)       0           dropout_28[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 1, 128)       0           dropout_42[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_4 (AveragePoo (None, 1, 128)       0           dropout_56[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_5 (AveragePoo (None, 1, 128)       0           dropout_70[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_6 (AveragePoo (None, 1, 128)       0           dropout_84[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_7 (AveragePoo (None, 1, 128)       0           dropout_98[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_8 (AveragePoo (None, 1, 128)       0           dropout_112[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_9 (AveragePoo (None, 1, 128)       0           dropout_126[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_10 (AveragePo (None, 1, 128)       0           dropout_140[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 128)       0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 1, 128)       0           average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 1, 128)       0           average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 1, 128)       0           average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 1, 128)       0           average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 1, 128)       0           average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 1, 128)       0           average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 1, 128)       0           average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 1, 128)       0           average_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 1, 128)       0           average_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 128)      0           activation_26[0][0]
#                                                                  activation_52[0][0]
#                                                                  activation_78[0][0]
#                                                                  activation_104[0][0]
#                                                                  activation_130[0][0]
#                                                                  activation_156[0][0]
#                                                                  activation_182[0][0]
#                                                                  activation_208[0][0]
#                                                                  activation_234[0][0]
#                                                                  activation_260[0][0]
# __________________________________________________________________________________________________
# dropout_141 (Dropout)           (None, 10, 128)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1280)         0           dropout_141[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 9)            11529       flatten_1[0][0]
# ==================================================================================================
# Total params: 26,050,889
# Trainable params: 26,014,409
# Non-trainable params: 36,480
# __________________________________________________________________________________________________

# %%
def read_data_seg(data_path, split = "Train",preprocess=False,fs=500,newFs=256,winSecond=10,winNum=10,n_index=0):
    """ Read data """

    # Fixed params
    #n_index = 0
    n_class = 9
    winSize = winSecond*fs
    new_winSize = winSecond*newFs
    # Paths
    path_signals = os.path.join(data_path, split)

    # Read labels and one-hot encode
    #label_path = os.path.join(data_path, "reference.txt")
    #labels = pd.read_csv(label_path, sep='\t',header = None)
    #labels = pd.read_csv("reference.csv")

    # Read time-series data
    channel_files = os.listdir(path_signals)
    #print(channel_files)
    channel_files.sort()
    n_channels = 12#len(channel_files)
    #posix = len(split) + 5

    # Initiate array
    list_of_channels = []
    
    X = np.zeros((len(channel_files), new_winSize, n_channels))
    i_ch = 0
    
    channel_name = ['V6', 'aVF', 'I', 'V4', 'V2', 'aVL', 'V1','II', 'aVR', 'V3', 'III', 'V5']
    channel_mid_name = ['II','aVR','V2','V5']
    channel_post_name = ['III','aVF','V3','V6']
    
    for i_ch,fil_ch in enumerate(channel_files[:]):#tqdm
        #print(fil_ch)
        ecg = sio.loadmat(os.path.join(path_signals,fil_ch))
        ecg_length = ecg["I"].shape[1]
        
        if ecg_length > fs*winNum*winSecond:
            print(" too long !!!",ecg_length)
            ecg_length = fs*winNum*winSecond
        if ecg_length < 4500:
            print(" too short !!!",ecg_length)
            break
        
        slide_steps = int((ecg_length- winSize)/winSecond)
        
        if ecg_length <= 4500:
            slide_steps = 0
            
        ecg_channels = np.zeros((new_winSize, n_channels))
        
        for i_n,ch_name in enumerate(channel_name):

            ecg_channels[:,i_n] = signal.resample(ecg[ch_name]
                                                  [:,n_index*slide_steps:n_index*slide_steps+winSize].T
                                                  ,new_winSize).T
            if preprocess:
                data = ecg_preprocessing(ecg_channels[:,i_n].reshape(1,new_winSize), 'sym8', 8, 3, newFs)
                ecg_channels[:,i_n] = data[0]
            else:
                pass
                ecg_channels[:,i_n] = ecg_channels[:,i_n]
                
        X[i_ch,:,:] = ecg_channels

    return X

# %%
ecg12_seg0 = read_data_seg(os.getcwd(),n_index=0)
ecg12_seg1 = read_data_seg(os.getcwd(),n_index=1)
ecg12_seg2 = read_data_seg(os.getcwd(),n_index=2)
ecg12_seg3 = read_data_seg(os.getcwd(),n_index=3)
ecg12_seg4 = read_data_seg(os.getcwd(),n_index=4)

# %%
ecg12_seg0.shape
# Out:
# (6500, 2560, 12)

# %%
ecg12_seg5 = read_data_seg(os.getcwd(),n_index=5)
ecg12_seg6 = read_data_seg(os.getcwd(),n_index=6)
ecg12_seg7 = read_data_seg(os.getcwd(),n_index=7)
ecg12_seg8 = read_data_seg(os.getcwd(),n_index=8)
ecg12_seg9 = read_data_seg(os.getcwd(),n_index=9)

# %%
ecg12_seg9.shape
# Out:
# (6500, 2560, 12)

# %%
class Config(object):
    def __init__(self):
        self.conv_subsample_lengths = [1, 2, 1, 2, 1, 2, 1, 2]
        self.conv_filter_length = 32
        self.conv_num_filters_start = 12
        self.conv_init = "he_normal"
        self.conv_activation = "relu"
        self.conv_dropout = 0.5
        self.conv_num_skip = 2
        self.conv_increase_channels_at = 2
        self.batch_size = 32#128
        self.input_shape = [2560, 12]#[1280, 1]
        self.num_categories = 2

    @staticmethod
    def lr_schedule(epoch):
        lr = 0.1
        if epoch >= 20 and epoch < 40:
            lr = 0.01
        if epoch >= 40:
            lr = 0.001
        print('Learning rate: ', lr)
        return lr

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
    
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
bin_label = np.zeros((6500,9))
for i in range(labels.shape[0]):
    label_nona = labels.loc[i].dropna()
    for j in range(1,label_nona.shape[0]):
        bin_label[i,int(label_nona[j])]=1

# %%
bin_label.shape
# Out:
# (6500, 9)

# %%
ecg12_seg0.shape
# Out:
# (6500, 2560, 12)

# %%
train_index = np.arange(6500)

# %%
train_index
# Out:
# array([   0,    1,    2, ..., 6497, 6498, 6499])

# %%
from sklearn.model_selection import train_test_split
index_tr, index_vld, lab_tr, lab_vld = train_test_split(train_index, labels['label1'], 
                                        stratify = labels['label1'], #test_size=0.1,
                                        shuffle=True, random_state = 123)

# %%
index_tr.shape
# Out:
# (4875,)

# %%
X_tr = [ecg12_seg0[index_tr],ecg12_seg1[index_tr],ecg12_seg2[index_tr],ecg12_seg3[index_tr],
        ecg12_seg4[index_tr],ecg12_seg5[index_tr],ecg12_seg6[index_tr],ecg12_seg7[index_tr],
        ecg12_seg8[index_tr],ecg12_seg9[index_tr],
       ]

# %%
index_vld.shape
# Out:
# (1625,)

# %%
X_vld = [ecg12_seg0[index_vld],ecg12_seg1[index_vld],ecg12_seg2[index_vld],ecg12_seg3[index_vld],
         ecg12_seg4[index_vld],ecg12_seg5[index_vld],ecg12_seg6[index_vld],ecg12_seg7[index_vld],
         ecg12_seg8[index_vld],ecg12_seg9[index_vld],
        ]

# %%
ecg12_seg0[index_vld].shape
# Out:
# (1625, 2560, 12)

# %%
def preprocess_y(y,num_class=9):
    bin_label = np.zeros((y.shape[0],num_class))
    for i in range(y.shape[0]):
        label_nona = labels.loc[lab_tr.index.tolist()[i]].dropna()
        for j in range(1,label_nona.shape[0]):
            bin_label[i,int(label_nona[j])]=1
    return bin_label

# %%
y_tr = preprocess_y(lab_tr)
y_vld = preprocess_y(lab_vld)

# %%
y_vld.shape
# Out:
# (1625, 9)

# %%
model_name = 'weights_best_resnet_model_23'

checkpointer = ModelCheckpoint(filepath=model_name+'.hdf5', 
                            monitor='val_fmeasure',verbose=1, save_weights_only=True,
                            save_best_only=True, mode='max')
reduce = ReduceLROnPlateau(monitor='val_fmeasure',factor=0.5,patience=2,verbose=1,min_delta=1e-4,mode='max')
''' 
model.compile(optimizer = 'adam',
           loss='binary_crossentropy',
           metrics=['accuracy',fmeasure,recall,precision])

epochs = 20

history = model.fit_generator(train_generator,
       validation_data = val_generator,
       epochs=epochs,
       callbacks=[checkpointer,reduce],
       verbose=1)
'''
pass

# %%
def add_compile(model, config):
    
    optimizer = SGD(lr=config.lr_schedule(0), momentum=0.9)#Adam()#
    model.compile(loss='binary_crossentropy',#weighted_loss,#'binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy',fmeasure,recall,precision])

# %%
import gc
if False:# True  False
    K.clear_session()
    gc.collect()
    config = tf.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    config.gpu_options.per_process_gpu_memory_fraction = 0.8

    session = tf.Session(config=config)

    KTF.set_session(session )

# %%
config = Config()
add_compile(model, config)

earlystop = EarlyStopping(
            monitor='val_fmeasure',#'val_categorical_accuracy',
            patience=10,
            )
checkpoint = ModelCheckpoint(filepath=model_name,
                             monitor='val_categorical_accuracy', mode='max',
                             save_best_only='True')

lr_scheduler = LearningRateScheduler(config.lr_schedule)

callback_lists = [checkpointer,reduce]#[checkpointer,earlystop,lr_scheduler]
#[checkpoint, earlystop,lr_scheduler] 

history = model.fit(x=X_tr, y=y_tr, batch_size=32, epochs=20,  #class_weight=cw,#'auto',
          verbose=1, validation_data=(X_vld, y_vld), callbacks=callback_lists )
# Out:
# Learning rate:  0.1
# WARNING:tensorflow:From /home/JDWorkSpace/vyuf0458/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4875 samples, validate on 1625 samples
# Epoch 1/20
# 4875/4875 [==============================] - 311s 64ms/step - loss: 0.2921 - acc: 0.8945 - fmeasure: 0.5516 - recall: 0.4735 - precision: 0.6968 - val_loss: 0.8590 - val_acc: 0.8254 - val_fmeasure: 0.2301 - val_recall: 0.1972 - val_precision: 0.2785
#
# Epoch 00001: val_fmeasure improved from -inf to 0.23007, saving model to weights_best_resnet_model_23.hdf5
# Epoch 2/20
# 4875/4875 [==============================] - 135s 28ms/step - loss: 0.2275 - acc: 0.9201 - fmeasure: 0.6524 - recall: 0.5776 - precision: 0.7638 - val_loss: 0.8621 - val_acc: 0.8156 - val_fmeasure: 0.1606 - val_recall: 0.1338 - val_precision: 0.2044
#
# Epoch 00002: val_fmeasure did not improve from 0.23007
# Epoch 3/20
# 4875/4875 [==============================] - 136s 28ms/step - loss: 0.1935 - acc: 0.9312 - fmeasure: 0.7118 - recall: 0.6571 - precision: 0.7858 - val_loss: 0.9071 - val_acc: 0.8223 - val_fmeasure: 0.2292 - val_recall: 0.2013 - val_precision: 0.2686
#
# Epoch 00003: val_fmeasure did not improve from 0.23007
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 4/20
# 4875/4875 [==============================] - 133s 27ms/step - loss: 0.1561 - acc: 0.9431 - fmeasure: 0.7659 - recall: 0.7132 - precision: 0.8338 - val_loss: 0.9505 - val_acc: 0.8075 - val_fmeasure: 0.2279 - val_recall: 0.2152 - val_precision: 0.2433
#
# Epoch 00004: val_fmeasure did not improve from 0.23007
# Epoch 5/20
# 4875/4875 [==============================] - 132s 27ms/step - loss: 0.1418 - acc: 0.9495 - fmeasure: 0.7947 - recall: 0.7517 - precision: 0.8486 - val_loss: 0.9518 - val_acc: 0.8074 - val_fmeasure: 0.1985 - val_recall: 0.1806 - val_precision: 0.2216
#
# Epoch 00005: val_fmeasure did not improve from 0.23007
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 6/20
# 4875/4875 [==============================] - 133s 27ms/step - loss: 0.1280 - acc: 0.9552 - fmeasure: 0.8198 - recall: 0.7796 - precision: 0.8692 - val_loss: 0.9161 - val_acc: 0.8066 - val_fmeasure: 0.2280 - val_recall: 0.2163 - val_precision: 0.2425
#
# Epoch 00006: val_fmeasure did not improve from 0.23007
# Epoch 7/20
# 4875/4875 [==============================] - 132s 27ms/step - loss: 0.1195 - acc: 0.9569 - fmeasure: 0.8275 - recall: 0.7900 - precision: 0.8728 - val_loss: 0.9727 - val_acc: 0.8038 - val_fmeasure: 0.2268 - val_recall: 0.2180 - val_precision: 0.2378
#
# Epoch 00007: val_fmeasure did not improve from 0.23007
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 8/20
# 4875/4875 [==============================] - 131s 27ms/step - loss: 0.1080 - acc: 0.9613 - fmeasure: 0.8464 - recall: 0.8137 - precision: 0.8858 - val_loss: 0.9648 - val_acc: 0.8031 - val_fmeasure: 0.2294 - val_recall: 0.2222 - val_precision: 0.2383
#
# Epoch 00008: val_fmeasure did not improve from 0.23007
# Epoch 9/20
# 4875/4875 [==============================] - 131s 27ms/step - loss: 0.1129 - acc: 0.9614 - fmeasure: 0.8468 - recall: 0.8157 - precision: 0.8844 - val_loss: 1.0582 - val_acc: 0.8018 - val_fmeasure: 0.2303 - val_recall: 0.2245 - val_precision: 0.2376
#
# Epoch 00009: val_fmeasure improved from 0.23007 to 0.23026, saving model to weights_best_resnet_model_23.hdf5
# Epoch 10/20
# 4875/4875 [==============================] - 130s 27ms/step - loss: 0.1041 - acc: 0.9636 - fmeasure: 0.8552 - recall: 0.8201 - precision: 0.8971 - val_loss: 1.0463 - val_acc: 0.8021 - val_fmeasure: 0.2262 - val_recall: 0.2191 - val_precision: 0.2352
#
# Epoch 00010: val_fmeasure did not improve from 0.23026
# Epoch 11/20
# 4875/4875 [==============================] - 130s 27ms/step - loss: 0.1005 - acc: 0.9649 - fmeasure: 0.8582 - recall: 0.8318 - precision: 0.8897 - val_loss: 1.0823 - val_acc: 0.8037 - val_fmeasure: 0.2252 - val_recall: 0.2158 - val_precision: 0.2368
#
# Epoch 00011: val_fmeasure did not improve from 0.23026
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 12/20
# 4875/4875 [==============================] - 131s 27ms/step - loss: 0.0971 - acc: 0.9656 - fmeasure: 0.8639 - recall: 0.8352 - precision: 0.8973 - val_loss: 1.0976 - val_acc: 0.8006 - val_fmeasure: 0.2242 - val_recall: 0.2182 - val_precision: 0.2318
#
# Epoch 00012: val_fmeasure did not improve from 0.23026
# Epoch 13/20
# 4875/4875 [==============================] - 132s 27ms/step - loss: 0.0908 - acc: 0.9672 - fmeasure: 0.8703 - recall: 0.8434 - precision: 0.9021 - val_loss: 1.1101 - val_acc: 0.8008 - val_fmeasure: 0.2272 - val_recall: 0.2217 - val_precision: 0.2342
#
# Epoch 00013: val_fmeasure did not improve from 0.23026
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 14/20
# 4875/4875 [==============================] - 134s 28ms/step - loss: 0.0844 - acc: 0.9697 - fmeasure: 0.8809 - recall: 0.8576 - precision: 0.9079 - val_loss: 1.1190 - val_acc: 0.7992 - val_fmeasure: 0.2228 - val_recall: 0.2180 - val_precision: 0.2289
#
# Epoch 00014: val_fmeasure did not improve from 0.23026
# Epoch 15/20
# 4875/4875 [==============================] - 132s 27ms/step - loss: 0.0907 - acc: 0.9699 - fmeasure: 0.8786 - recall: 0.8540 - precision: 0.9068 - val_loss: 1.1327 - val_acc: 0.7986 - val_fmeasure: 0.2220 - val_recall: 0.2176 - val_precision: 0.2278
#
# Epoch 00015: val_fmeasure did not improve from 0.23026
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 16/20
# 4875/4875 [==============================] - 131s 27ms/step - loss: 0.0856 - acc: 0.9709 - fmeasure: 0.8855 - recall: 0.8639 - precision: 0.9114 - val_loss: 1.1522 - val_acc: 0.7986 - val_fmeasure: 0.2231 - val_recall: 0.2192 - val_precision: 0.2284
#
# Epoch 00016: val_fmeasure did not improve from 0.23026
# Epoch 17/20
# 4875/4875 [==============================] - 130s 27ms/step - loss: 0.0867 - acc: 0.9700 - fmeasure: 0.8785 - recall: 0.8545 - precision: 0.9064 - val_loss: 1.1602 - val_acc: 0.7988 - val_fmeasure: 0.2230 - val_recall: 0.2191 - val_precision: 0.2284
#
# Epoch 00017: val_fmeasure did not improve from 0.23026
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 18/20
# 4875/4875 [==============================] - 131s 27ms/step - loss: 0.0846 - acc: 0.9710 - fmeasure: 0.8856 - recall: 0.8617 - precision: 0.9134 - val_loss: 1.1677 - val_acc: 0.7986 - val_fmeasure: 0.2226 - val_recall: 0.2186 - val_precision: 0.2282
#
# Epoch 00018: val_fmeasure did not improve from 0.23026
# Epoch 19/20
# 4875/4875 [==============================] - 132s 27ms/step - loss: 0.0822 - acc: 0.9706 - fmeasure: 0.8838 - recall: 0.8607 - precision: 0.9108 - val_loss: 1.1718 - val_acc: 0.7983 - val_fmeasure: 0.2216 - val_recall: 0.2176 - val_precision: 0.2271
#
# Epoch 00019: val_fmeasure did not improve from 0.23026
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 20/20
# 4875/4875 [==============================] - 130s 27ms/step - loss: 0.0830 - acc: 0.9708 - fmeasure: 0.8854 - recall: 0.8630 - precision: 0.9113 - val_loss: 1.1803 - val_acc: 0.7982 - val_fmeasure: 0.2223 - val_recall: 0.2186 - val_precision: 0.2275
#
# Epoch 00020: val_fmeasure did not improve from 0.23026

# %%
#save model
model_json = model.to_json()
with open(model_name+'.json','w') as json_file:
    json_file.write(model_json)
json_file.close()

# %%
from keras.models import model_from_json
with open(model_name+'.json','r') as json_file:
    load_model_json = json_file.read()
json_file.close()

model = model_from_json(load_model_json)
model.load_weights(model_name+'.hdf5')

# %%
test_x_seg0 = read_data_seg(os.getcwd(),split='Val',n_index=0)
test_x_seg1 = read_data_seg(os.getcwd(),split='Val',n_index=1)
test_x_seg2 = read_data_seg(os.getcwd(),split='Val',n_index=2)
test_x_seg3 = read_data_seg(os.getcwd(),split='Val',n_index=3)
test_x_seg4 = read_data_seg(os.getcwd(),split='Val',n_index=4)

# %%
test_x_seg5 = read_data_seg(os.getcwd(),split='Val',n_index=5)
test_x_seg6 = read_data_seg(os.getcwd(),split='Val',n_index=6)
test_x_seg7 = read_data_seg(os.getcwd(),split='Val',n_index=7)
test_x_seg8 = read_data_seg(os.getcwd(),split='Val',n_index=8)
test_x_seg9 = read_data_seg(os.getcwd(),split='Val',n_index=9)

# %%
test_x = [test_x_seg0,test_x_seg1,test_x_seg2,test_x_seg3,test_x_seg4,
          test_x_seg5,test_x_seg6,test_x_seg7,test_x_seg8,test_x_seg9,
         ]

# %%
test_y = model.predict(test_x)

# %%
test_y
# Out:
# array([[9.4034564e-01, 3.3974648e-06, 7.0512295e-05, ..., 6.2715411e-03,
#         1.9216359e-02, 3.3553839e-03],
#        [2.0529687e-02, 2.1192431e-04, 8.7180734e-04, ..., 1.1174917e-02,
#         4.7087669e-05, 1.3118297e-02],
#        [1.9669533e-04, 8.1126344e-01, 1.0361940e-02, ..., 4.9620777e-02,
#         4.6044588e-05, 8.0512315e-01],
#        ...,
#        [5.9604645e-08, 8.8751316e-04, 1.9134283e-03, ..., 3.0768812e-02,
#         9.2387199e-07, 1.8979907e-03],
#        [1.6311765e-02, 7.2371960e-04, 6.6626751e-01, ..., 1.5119076e-02,
#         7.0303679e-05, 7.2297513e-01],
#        [9.4874060e-01, 3.8146973e-05, 2.7394295e-04, ..., 2.7952641e-02,
#         1.3104081e-04, 5.5548251e-03]], dtype=float32)

# %%
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import hamming_loss
import csv

# %%
train_x = [ecg12_seg0[:],ecg12_seg1[:],ecg12_seg2[:],ecg12_seg3[:],
           ecg12_seg4[:],ecg12_seg5[:],ecg12_seg6[:],ecg12_seg7[:],
           ecg12_seg8[:],ecg12_seg9[:],
          ]

# %%
x_tr_y = model.predict(train_x)#X_tr

threshold = np.arange(0.1,0.9,0.1)

out = x_tr_y
y_test = bin_label#y_tr

acc = []
accuracies = []
best_threshold = np.zeros(out.shape[1])
for i in range(out.shape[1]):
    y_prob = np.array(out[:,i])
    for j in threshold:
        y_pred = [1 if prob>=j else 0 for prob in y_prob]
        acc.append( matthews_corrcoef(y_test[:,i],y_pred))
    acc   = np.array(acc)
    index = np.where(acc==acc.max()) 
    accuracies.append(acc.max()) 
    best_threshold[i] = threshold[index[0][0]]
    acc = []

print("best_threshold: ",best_threshold)

y_pred = np.array([[1 if out[i,j]>=best_threshold[j] else 0 for j in range(y_test.shape[1])] for i in range(len(y_test))])

y_pred 

y_test

#best_threshold:  [0.7 0.4 0.5 0.4 0.3 0.2 0.3 0.4 0.4]
#0.022393162393162393

hamming_loss(y_test,y_pred)
# Out:
# best_threshold:  [0.5 0.3 0.4 0.1 0.2 0.2 0.2 0.1 0.7]
# 0.02634188034188034

# %%
for i,v in enumerate(best_threshold):
    if v > 0.1:
        best_threshold[i] =  v# - 0.1
best_threshold#array([0.8, 0.6, 0.5, 0.1, 0.3, 0.3, 0.4, 0.3, 0.4])
# Out:
# array([0.5, 0.3, 0.4, 0.1, 0.2, 0.2, 0.2, 0.1, 0.7])

# %%
classes = [0,1,2,3,4,5,6,7,8]

y_pred = [[1 if test_y[i,j]>=best_threshold[j] else 0 for j in range(test_y.shape[1])] 
          for i in range(len(test_y))]
pred=[]
for j in range(test_y.shape[0]):
    pred.append([classes[i] for i in range(9) if y_pred[j][i] == 1])

with open('answers116.csv','w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['File_name', 'label1', 'label2',
                    'label3', 'label4', 'label5', 'label6', 'label7', 'label8'])
    count = 0
    for file_name in val_files:
        if file_name.endswith('.mat'):
            
            record_name = file_name.strip('.mat')
            answer = []
            answer.append(record_name)
            
            result = pred[count]
            
            answer.extend(result)
            for i in range(8-len(result)):
                answer.append('')
                
            #print(answer)
            count += 1
            writer.writerow(answer)
    csvfile.close()

# %%
import csv
thred = 0.15
''' 
pred = []
for i in range(test_y.shape[0]):
    
    try:
        pred_list = list(np.hstack(np.argwhere(test_y[i]>thred)))
    except ValueError:
        print(" ValueError !!! ")
        pred_list = ['']
        
    pred.append(pred_list)
    
with open('answers66.csv','w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['File_name', 'label1', 'label2',
                    'label3', 'label4', 'label5', 'label6', 'label7', 'label8'])
    count = 0
    for file_name in val_files:
        if file_name.endswith('.mat'):
            
            record_name = file_name.strip('.mat')
            answer = []
            answer.append(record_name)
            
            result = pred[count]
            
            answer.extend(result)
            for i in range(8-len(result)):
                answer.append('')
                
            #print(answer)
            count += 1
            writer.writerow(answer)
    csvfile.close()
'''
pass
